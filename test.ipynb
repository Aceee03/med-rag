# %%
# Out:
# 1. Initializing OpenAI (gpt-4o-mini)...
# 2. Building the Strict Medical Schema...
# 3. Injecting the 'Brochure-Aware' Translation Prompt...
# 4. Constructing the Knowledge Graph (Running extraction on nodes)...
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 50
#      48 print("4. Constructing the Knowledge Graph (Running extraction on nodes)...")
#      49 # Let's run it on the first 30 nodes so we get a solid chunk of data
# ---> 50 test_nodes = enriched_nodes[:30]
#      52 index = PropertyGraphIndex(
#      53     nodes=test_nodes,
#      54     kg_extractors=[smart_extractor],
#      55     show_progress=True
#      56 )
#      58 print("\n✅ Graph Constructed! Let's view the extracted triplets:\n")
#
# NameError: name 'enriched_nodes' is not defined
